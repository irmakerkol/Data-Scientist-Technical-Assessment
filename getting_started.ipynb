# %% [markdown]
# # Papcorns Data Scientist Task - Getting Started
#
# This notebook will help you get started with the Papcorns data scientist technical assessment. We'll show you how to:
# 1. Install requirements and do the imports
# 2. Connect to the SQLite database
# 3. Load the data into pandas DataFrames
#
# First, let's import the required libraries:

# %% [markdown]
# ## Installing Requirements
#
# Let's install the required libraries:

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: numpy in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: seaborn in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: jupyter in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from -r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: notebook in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (7.4.0)
# Requirement already satisfied: jupyter-console in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (8.1.6)
# Requirement already satisfied: jupyterlab in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 5)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 5)) (3.0.14)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 5)) (3.0.48)
# Requirement already satisfied: pygments in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 5)) (75.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 5)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: anyio in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: certifi in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.0.8)
# Requirement already satisfied: idna in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: decorator in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.6.2)
# Requirement already satisfied: colorama in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 5)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 5)) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 5)) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 5)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 5)) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 5)) (4.12.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\suuser\appdata\local\anaconda3\envs\dsa201\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 5)) (2.9.0.20241206)

# %% [markdown]
# ## Imports
#
# Let's do the imports:

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Set plotting style
#plt.style.use('seaborn')
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('deep')

# %% [markdown]
# ## Connecting to the Database
#
# Let's establish a connection to the SQLite database:

# %%
# Connect to the SQLite database
conn = sqlite3.connect('papcorns.sqlite')

# %% [markdown]
# ## Exploring the Data Structure
#
# Let's look at the structure of our tables:

# %%
# Load users table
users_df = pd.read_sql_query("SELECT * FROM users LIMIT 5;", conn)
print("Users table preview:")
display(users_df)

# Load events table
events_df = pd.read_sql_query("SELECT * FROM user_events LIMIT 5;", conn)
print("\nUser events table preview:")
display(events_df)
# Out:
# Users table preview:
#    id           created_at attribution_source country          name
# 0   1  2024-05-07T00:00:00          instagram      US     Eve Brown
# 1   2  2024-10-12T00:00:00          instagram      NL   Frank Moore
# 2   3  2024-10-15T00:00:00             tiktok      TR  Ivy Anderson
# 3   4  2024-08-28T00:00:00             tiktok      TR   Alice Brown
# 4   5  2024-04-03T00:00:00            organic      NL     Bob Moore
# User events table preview:
#    id           created_at  user_id       event_name amount_usd
# 0   1  2024-05-07T00:00:00        1      app_install       None
# 1   2  2024-05-12T00:00:00        1    trial_started       None
# 2   3  2024-05-24T00:00:00        1  trial_cancelled       None
# 3   4  2024-10-12T00:00:00        2      app_install       None
# 4   5  2024-10-13T00:00:00        2    trial_started       None
